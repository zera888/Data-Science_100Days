# %%
#對以下成績資料做分析

#    6 號學生(student_id=6) 3 科平均分數為何？
#    6 號學生 3 科平均分數是否有贏過班上一半的同學？
#    由於班上同學成績不好，所以學校統一加分，加分方式為開根號乘以十，請問 6 號同學 3 科成績分別是？
#    承上題，加分後各科班平均變多少？


#score_df = pd.DataFrame([[1,56,66,70], [2,90,45,34], [3,45,32,55], [4,70,77,89], [5,56,80,70], [6,60,54,55], [7,45,70,79], [8,34,77,76],
#                            [9,25,87,60], [10,88,40,43]],columns=['student_id','math_score','english_score','chinese_score'])


import pandas as pd
import numpy as np
df1 = pd.DataFrame([[1,56,66,70], [2,90,45,34], [3,45,32,55], [4,70,77,89], [5,56,80,70], [6,60,54,55], [7,45,70,79], [8,34,77,76],
                           [9,25,87,60], [10,88,40,43]],columns=['student_id','math_score','english_score','chinese_score'])
print('全班學生成績如下:')
mean_df = df1.mean(axis=1)
df1["score_avg"] =mean_df
print(df1)
print()

#    6 號學生(student_id=6) 3 科平均分數為何？
print('六號學生平均分數如下:')
df2 = df1.loc[5 ,[ 'score_avg'] ]
print(df2)
print()

#    6 號學生 3 科平均分數是否有贏過班上一半的同學？
print('班上成績的中位數為:')
median_df = df1.score_avg.median()
print(median_df)
if df2.values >= median_df:
    print('第六位同學的成績高於班上的一半的同學。\n')
else:
    print('第六位同學的成績並沒有贏過班上一半的同學\n')
    
#    由於班上同學成績不好，所以學校統一加分，加分方式為開根號乘以十，請問 6 號同學 3 科成績分別是？
print('全班同學加分後成績如下：\n')
df3 = df1
f = lambda x : x**(0.5)*10
df3['math_score'] = df3['math_score'].apply(f)
df3['english_score'] = df3['english_score'].apply(f)
df3['chinese_score'] = df3['chinese_score'].apply(f)
df3['score_avg'] = df3['score_avg'].apply(f)
print(df3)
print()
print('第六位同學的成績加分後為:\n')
id6 =df3.loc[ 5 , : ]
print(id6)
print()

#    承上題，加分後各科班平均變多少？
print('各科加分之後的成績如下：\n')
print('數學科的平均分數是：',df3.math_score.mean())
print('英文科的平均分數是:',df3.english_score.mean())
print('國文科的平均分數是:',df3.chinese_score.mean())
# Out:
# 全班學生成績如下:
#    student_id  math_score  english_score  chinese_score  score_avg
# 0           1          56             66             70      48.25
# 1           2          90             45             34      42.75
# 2           3          45             32             55      33.75
# 3           4          70             77             89      60.00
# 4           5          56             80             70      52.75
# 5           6          60             54             55      43.75
# 6           7          45             70             79      50.25
# 7           8          34             77             76      48.75
# 8           9          25             87             60      45.25
# 9          10          88             40             43      45.25
#
# 六號學生平均分數如下:
# score_avg    43.75
# Name: 5, dtype: float64
#
# 班上成績的中位數為:
# 46.75
# 第六位同學的成績並沒有贏過班上一半的同學
#
# 全班同學加分後成績如下：
#
#    student_id  math_score  english_score  chinese_score  score_avg
# ...
